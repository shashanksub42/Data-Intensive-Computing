# %%
import pandas as pd
import nltk
import numpy as np
import matplotlib.pyplot as plt
import re
from nltk.tokenize import WordPunctTokenizer
import warnings
warnings.filterwarnings("ignore")
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn import naive_bayes
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import operator

# %%
data = pd.read_csv("/import_tweets1.csv")

# %%
data.head()
# Out:
#              tweet_id                      created_on  \
# 0  986283984303816000  Tue Apr 17 16:43:20 +0000 2018
# 1  986283986149404000  Tue Apr 17 16:43:21 +0000 2018
# 2  986283986480717000  Tue Apr 17 16:43:21 +0000 2018
# 3  986283990842781000  Tue Apr 17 16:43:22 +0000 2018
# 4  986283991090286000  Tue Apr 17 16:43:22 +0000 2018
#
#                                                 text
# 0  @u6239 @Argyll_IslesApp @Arsenal Wow, brave pe...
# 1  RT @PeterMooreLFC: They have a stadium, we hav...
# 2  RT @BarcaTimes: ðŸ“°[SPORT] | King of Spain Ph...
# 3  RT @LFC: We are Liverpool. The story continues...
# 4  Panathinaikos clear ex-Chelsea star Michael Es...

# %%
df = data[['text']]

# %%
for i in range(0, len(df)):
    df.text[i] = re.sub(r'@[A-Za-z0-9]+','',str(df.text[i]))

# %%
df.head()
# Out:
#                                                 text
# 0   _IslesApp  Wow, brave people ðŸ™„ Bit cold fo...
# 1  RT : They have a stadium, we have a home. They...
# 2  RT : ðŸ“°[SPORT] | King of Spain Philippe VI c...
# 3  RT : We are Liverpool. The story continues... ...
# 4  Panathinaikos clear ex-Chelsea star Michael Es...

# %%
for t in df: 
    df[t].replace(u"\ufffd", "?")

# %%
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))
def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()
testing = df['text']
test_result = []
for t in testing:
    test_result.append(tweet_cleaner(t))
test_result
# Out:
# ['islesapp wow brave people bit cold for me',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt sport king of spain philippe vi confirms his attendance at the final of copa del rey to be held coming saturday at the',
#  'rt we are liverpool the story continues',
#  'panathinaikos clear ex chelsea star michael essien debt in bid to avoid relegation',
#  'rt chelsea winning against spurs is by far my favourite recent memory of us at wembley',
#  'rt chelsea to rival arsenal for aleksandr golovin cfc',
#  'rt we are liverpool the story continues',
#  'united are starting voting for the poty awards just seen the shortlist for goal of the season and for me it s out',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'these people really think it s as simple as picking the right formation and plugging the players in',
#  'rt we are liverpool the story continues',
#  'i am very sure vidal doesn t have this much hair on his head',
#  'rt we are liverpool the story continues',
#  'rt back in the states',
#  'rt td para m el nico equipo mexicano que representa al pa s en cualquier competencia internacional es la selecci n nacional',
#  'ye the funny thing is that rome is like an hour away from where i live and flights are expensive as f',
#  'rt in the last months man utd have beaten',
#  'if the roles were reversed he would threaten to kick bar a out of la liga if we didn t do it dumb fascist asshole',
#  'wow who hasn t scored for liverpool under klopp',
#  'rt kudos to the social media team for pulling this together so quickly after that monstrosity from man city',
#  'athletic club s ziganda real madrid made mistakes at home in the first half of the season which saw them lose a g',
#  'rt styles harry s a fan of packers they re awesome man',
#  'lol when will this madridista fraud stop running our league',
#  'rt we are liverpool the story continues',
#  'rt official mufc to play ac milan th july liverpool th july and real madrid st july in the international ch',
#  'rt sleeps until the start of spring festival we re so excited to be the official travel partners m',
#  'liverpool are lucky to have complete player roberto firmino says former winger dirk kuyt',
#  'zinedine zidane penggemar real madrid makin banyak',
#  'rt mohamed salah in for liverpool',
#  'rt dimmi cos e',
#  'man city to face liverpool bayern munich and borussia dortmund in international champions cup espn press releas',
#  'rt snr because barcelona fans prefer to discuss madrid more than focus on their team real madrid have lost t',
#  'rt my latest for on liverpool s fight with a youth soccer club in the us over the use of trademarks',
#  'rt',
#  'rt salah is making all the headlines but liverpool s complete player firmino is the standout for one former star',
#  'facupsemifinal chelsea v southampton',
#  'rt arsenal will face atletico madrid july th psg july th and chelsea aug th in international champions cup https',
#  'se me perco no kilamba imagina a possas',
#  'rt we are liverpool the story continues',
#  'rt what a partnership this would be',
#  'rt harry performing in barcelona',
#  '',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'connect man city assets will be very popular for the captaincy especially with liverpool playing t',
#  'barcelona celta vigo',
#  'rt mental to think manchester united once had rooney ronaldo berbatov and tevez all in one squad under sir alex ferguso',
#  'rt mo salah world class but not every day sadio man world class but not every day roberto firmino world class pretty',
#  'rt liverpool s trent alexander arnold triggers pay rise in contract source via',
#  'watch jurgen klopp feature in incredible liverpool fc this means more promo video',
#  'rt wenn man in bayern wohnt und tweetet dass man sterben will',
#  'rt bayern will psychisch kranke wie straft ter behandeln',
#  'it s you',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'the league president is a madrid fan and he does nothing to hide it this statement makes no sense',
#  'this is epic it gave me chills ynwa',
#  '',
#  'rt gifs si cristiano ronaldo hubiera jugado en espa a con el real madrid desde el comienzo de su carrera ahora mismo tendr a',
#  'rt arsenal vs psg',
#  'rt we are liverpool the story continues',
#  'rt en the last meetings between tonight s two semi finalists',
#  'rt back in the states',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'rt happy birthday all the best for you and your family bro yagunnersya',
#  'rt our fixtures in this summer s international champions cup have been announced with chelsea set to play matches in sweden an',
#  'liverpool to reward goalkeeper with an improved contract',
#  'rt dele alli waving goodbye to chelsea s chances of breaking the record for most consecutive wins like',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'couldn t of said it better myself',
#  'rt o dia em que o homem destruiu o bayern',
#  'rt arsenal flop mathieu debuchy is the highest scoring defender in europe s top five leagues with as many goals this season',
#  'epl burnley vs chelsea team news injuries possible lineups',
#  'rt mental to think manchester united once had rooney ronaldo berbatov and tevez all in one squad under sir alex ferguso',
#  'rt goals in games under j rgen klopp and clean sheets in the this season',
#  'rt roma calvario infinito servizi inesistenti romani furiosi',
#  'rt photos amir khan open workout for liverpool ring return',
#  'when judgement day comes i ll make sure am wearing my arsenal jersey so that god knows i ve already been through hell arsenal',
#  'rt b can confirm this caller was',
#  'rt poiis who s better',
#  'rt we are liverpool the story continues',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'spot on except it s too soon for mavropanos and i d play mkhi over laca',
#  'ha perdido la cabeza la presentadora de concursos y ex cheerleader de barcelona',
#  'rt vienna italia rt gianluca teseo teseo il colosseo si tinge di rosso per non dimenticare i cristiani perseg',
#  'rt what a summer',
#  '',
#  'rt fr les derniers matchs de cheick diabat benevento',
#  'rt most ignorant illiterate gun tweet ever of all of the activists who have sprung up in the wake of parkland shooting',
#  'rt what a summer',
#  'se penal li ta pral rate nan semi a anyways',
#  'rt ruscoe big debate who are the bigger club right now',
#  'exeter gent doncaster zwole sevilla eastleigh rochdale toronto up lincoln up cagliari brighton dumbarton surprise myplay',
#  'rt we are liverpool the story continues',
#  'arsenal are looking to sign juventus defender daniele rugani source il posticipo',
#  'rt tickets for the first leg of our fa youth cup final against arsenal on friday april at the bridge are now on general sa',
#  'vabene non mi sta bene mai niente e anzich trovare le cose da fare continuo a lamentarmi ma ho cercato qualcosa da',
#  'rt archie goals assists more tackles than any defender from the top pl clubs this season bar azpilicueta a tactical loo',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'facupsemifinal chelsea v southampton',
#  'rt we are liverpool the story continues',
#  'rt spurs v roma in san diego',
#  'rt martial mixtape vol',
#  'barcelona fcb messi campnou noucampexperience barcelona fc nou camp stadium',
#  'rt we are liverpool',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'salam to real madrid this summer next season liverpool back where they belong mid table',
#  'rt can imagine the smile on txiki s face when he goes to pay liverpool that m due to sterling winning the league lmao',
#  'rt no fair enough he helped us get here but he also refused to play our qualifier if a player willing to risk our entir',
#  'rt cervera no pero sabino arana conserva su calle en barcelona',
#  'rt we are liverpool the story continues',
#  'rt martin oh shit barcelona playing in arlington i m about to buy my ticket right away',
#  'rt we are liverpool the story continues',
#  'rt is your arsenal a late bloomer this season get into the spirit of spring with up to off platinum on xbox one https',
#  'rt pogba is more than just a player at manchester united chances of him leaving next summer are close to zero ignore the nois',
#  'what a tweet always knew there were decent liverpool fans out there',
#  'rt arsenal s away agony',
#  'how much liverpool have already earned from champions league',
#  'rt martial mixtape vol',
#  'breaking arturo vidal ruled out for the rest of the season including real madrid clash',
#  '',
#  'rt we are liverpool the story continues',
#  'rt carroll our confirmed icc fixtures in the united states this summer',
#  'rt el estado indemnizar a los damnificados por la explosi n del arsenal de r o tercero ojal macri nos pagara la que nos deb',
#  'rt he s kindly donated i m doing a big charity thing at the end of the year for national autistic society and he s donated f',
#  'rt we are liverpool the story continues',
#  'rt dialogue eu catalonia dialogue platform will be presented next friday at am in barcelona all of you are invited',
#  'rt crouchyyyy chelsea should have signed crouch he s out here banging in the goals and morata is always kissing his wife on inst',
#  'rt answer ac milan liverpool in istanbul',
#  'rt arroba karol sevilla deja de hacerte la que no shippea lutteo ahre vieron como sonr e cuando nombra el shipp jajajaj',
#  'wow',
#  'rt they have to learn to defend for me now when arsenal go to pre season they can t think about scoring goals they are',
#  'ziganda when real madrid plays well they win and when they don t play well they still usually win',
#  'rt for what game',
#  '',
#  'i m so in between i really want the chelsea matte black rainboots and i know target will carry',
#  'some context to the idiotic tweets coming out about mustafi today any more nonsense that needs to be shut down th',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt this weekend brought us two more major demonstrations in spain in iru ea pamplona on saturday and barcelona on sunday th',
#  'facupsemifinal chelsea v southampton',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt dame una a',
#  '',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'rt breaking monaco vice president vadim vasilyev has claimed that he would prefer to sell their midfielder thomas lemar',
#  'cech ingin arsenal sapu bersih semua laga sisa musim ini',
#  'rt manchester united liverpool will play at michigan stadium on july pm general public tickets go on sale april',
#  'rt man united s season',
#  'rt manchester united will only sell anthony martial if they receive a bid of at least million source calciomercato',
#  'i will love you forever and always for being there when i had everything and for when i had nothing',
#  'rt we are liverpool the story continues',
#  'rt jesus christ whoever made this lfc',
#  'rt horse dies while others collapse from exhaustion at feria de abril de sevilla in andalucia https',
#  'rt most journalists wouldn t have a career without manchester united',
#  'rt we need your help',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'en vivo deportivo vs sevilla en vivo a course in miracles lounge',
#  'take part now in the gazprom football experience and win an unforgettable fan experience for the match between as r',
#  'rt we are liverpool the story continues',
#  'rt hundreds of thousands of demonstrators took to the streets of barcelona to demand to call for their leaders release from pret',
#  'rt ltima hora arturo vidal se perder lo que resta de temporada y no podr jugar contra el real madrid',
#  'rt el an lisis de del choque contra sus excompa eros del real madrid',
#  'looking forward to tonight even though not expecting any points i booked my holiday after',
#  'rt revival this new monstrosity in liverpool is the national architecture centre and has been shortlisted for building of the de',
#  'rt manchester city have now won the premier league three times in seven years this is what happened in the first of those',
#  'rt we are liverpool the story continues',
#  'rt exposing the myth that real madrid are favored by uefa',
#  'liverpool fc news trent alexander arnold set for huge pay rise after triggering incentive bonus on contract',
#  'rt saatnya untuk bangkit dan meraih kemenangan jangan sampai lewatkan afc bournemouth vs manchester united kamis april',
#  'rt th j cole drops album',
#  'rt conjuntament a new form of citizen participation arises in barcelona combining participatory budgets and crowdfunding',
#  'rt we are liverpool the story continues',
#  '',
#  'rt liverpool are now the only team in all four divisions who are unbeaten at home',
#  'rt we are liverpool the story continues',
#  '',
#  'ynwa',
#  'gemeter',
#  'this means more ynwa',
#  'normally hate cringey videos clubs do but this is boss haha',
#  'bournemouth vs manchester united match preview betting tips',
#  'rt marco verratti convinced he made right decision to stay with psg amid interest from barcelona',
#  'rt martial mixtape vol',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'we ve won more achieved more and mean more than your football club could ever ever dream of freddy son',
#  'up the fuckin reds',
#  'metro sport claude puel sends message to manchester united over harry maguire transfer interest',
#  'rt poiis who s better',
#  'el arsenal visita al newcastle para consolidar el sexto puesto el arsenal visita ma ana',
#  'rt voting is now open for the chelsea player of the year award',
#  '',
#  'rt arsenal s away agony',
#  'facupsemifinal chelsea v southampton',
#  'we conquered all of europe we re never gonna stop',
#  'rt england u defender trent alexander arnold has committed his future to liverpool and is set to see his wages double',
#  'former arsenal defender mathieu debuchy has bagged four goals since joining st et',
#  'rt si la as roma elimina al fc barcelona sorteo fp entre todos los que me sigan y den rt a este tweet f jate en lo que',
#  'rt last caller on talksport a manchester united fan who wants his team to lose at the weekend just so mourinho gets the sack t',
#  'premier league paul merson makes huge prediction for chelsea vs burnley match via naijaloa',
#  'rt watch clauses triggered due after city s title win telegraph',
#  'ugh already looking trophyless for season',
#  'panathinaikos clear ex chelsea star michael essien debt in bid to avoid relegation',
#  'can t think of a perfect phil replacement than paulo dybala fuck me he d be an upgrade can play lw rw cam or cf',
#  'rt jurgen klopp',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt we are liverpool the story continues',
#  'rt liverpool number target for russia',
#  'rt we are liverpool the story continues',
#  'i believe in serie b they once maths me proud i will edit with win gg with accrington and bayern',
#  'me ha gustado un v deo de dibujos soy luna karol sevilla nada de perfectas',
#  'rt we are liverpool the story continues',
#  'rt quien es de barcelona os quiero ver',
#  'i m sorry this is too funny',
#  'il festival delle scienze di roma sull onda del jazz',
#  'spurs ey so if moura or lamela came into the starting xi instead of eriksen arsenal would have a point swing on us',
#  'rt we are liverpool the story continues',
#  'erick amigo en barcelona puedes encontrarnos a trav s de distribuciones enovin s l',
#  'we going to miami for mcfc vs bayern',
#  'william f buckley denounced the day after because it was part of a campaign to debilitate the defense of the us b',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'rt in the summer of real madrid signed cristiano ronaldo karim benzema kaka xabi alonso',
#  'seen as we re family can you sort me roma',
#  'bau bakalan di permanenkan psv dan akhirnya sukses chelsea lagi yg rugi',
#  'rt we are liverpool the story continues',
#  'rt barcelona midfielder andres iniesta will move to the chinese super league this summer with two million bottles of win',
#  'rt we are liverpool the story continues',
#  'rt arsenal vs psg',
#  'rt we are liverpool the story continues',
#  '',
#  'rt bayern is coming to miami this is the best day of my life ahhhhh',
#  'rt martial mixtape vol',
#  'manchester united fc',
#  'rt arsenal vs psg',
#  'rt roman s having sex again by nikkiashton',
#  'rt we are liverpool the story continues',
#  'kyle kashuv owns chelsea handler for most ignorant gun tweet ever',
#  'rt according to arsenal need an anchorman to protect the defense he then offers kerem demirbay an at',
#  'rt in den ern wollte bayern hiv positive internieren lassen heute sollen menschen mit psychischen krankheiten kriminalisiert',
#  'cat barcelona fcb messi campnou noucampexperience barcelona fc nou camp stadium',
#  'liverpool fc this means more lfc',
#  'even if every fan is thousands of miles away from liverpool',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'kyle kashuv owns chelsea handler for most ignorant gun tweet ever',
#  'rt we are liverpool the story continues',
#  'ahahah even better all bangers black gloves though',
#  'rt win tomorrow at bournemouth regain a point lead over liverpool lose we re back in the mess essential to finish ab',
#  'rt today in singapore to launch the international champions cup with',
#  'has lost to arsenal on aggregate',
#  'rt martial mixtape vol',
#  'rt old money acapella',
#  '',
#  'rt happy birthday all the best for you and your family bro yagunnersya',
#  'although i m not from wolverhampton myself it s not even nearly the size of london',
#  'rt according to gazzetta dello sport fcbayern and juventus are both interested in anthony martial but bayern are leading',
#  'didier drogba to expand luxury footwear brand as chelsea legend cuts price of trainers',
#  'rt we are liverpool the story continues',
#  'rt what a summer',
#  '',
#  'rt we are liverpool the story continues',
#  'your a chelsea fan and has seen your team get points in months so no matter which',
#  'rt mental to think manchester united once had rooney ronaldo berbatov and tevez all in one squad under sir alex ferguso',
#  'rt we are liverpool the story continues',
#  'rt freestyle extraordinaire takes on chelsea s academy some serious skills on display',
#  'rt we are liverpool the story continues',
#  'rt liverpool will go into the premier league campaign as second favourites to win',
#  'rt arsenal transfer window preview who stays who leaves and who gunners will target',
#  'so roma and juve have a game each in the tri state area for but chose to stick to the we',
#  'rt crotonejuve i convocati della juventus finoallafine',
#  'rt mac train back to liverpool from aintree ha ha',
#  'rt manchester united',
#  'barcelona is coming to arlington',
#  'rt england u defender trent alexander arnold has committed his future to liverpool and is set to see his wages double',
#  'this choked me up hard to explain what being a red means lfc ynwa',
#  'rt d abril baluard de santa madrona la coronela de barcelona recordant als germans valencians',
#  '',
#  'rt exposing the myth that real madrid are favored by uefa',
#  'fa charges chelsea s alonso with violent conduct',
#  'rt should bar a be given a guard of honor',
#  'rt plastic sheets cleared mins ago trains coming in and out from colchester and sheffield why am i still sit',
#  'rt watch clauses triggered due after city s title win telegraph',
#  'this guy hasn t rts',
#  'rt notice of appeal was served to supreme court at pm this afternoon alfieevans releasealfieeva',
#  'rt we are liverpool the story continues',
#  'rt chelsea star marcos alonso facing three match ban after being charged by the fa',
#  'rt dear arsenal before you bother sending out my season ticket renewals please consider that i m not renewing if arsene we',
#  'he needs a ticket for west brom liverpool',
#  'rt we are liverpool the story continues',
#  'so hold up we could have done it fine a decade ago now you re concerned about madrid s feelings foh',
#  'rt',
#  'rt we are liverpool the story continues',
#  'tipster can t see juventus making it back to back mms',
#  'rt my view on pogba is that he s played consistently he s had the opportunity he s appeared many times in his favoured p',
#  'rt bayern confirm arturo vidal will miss remainder of the season after having surgery on his knee today',
#  'frenchie islesapp and my we dog jules',
#  'rt we are liverpool the story continues',
#  'born in burnley so might have something to do with that lol',
#  'euroleague panathinaikos realmadrid',
#  'rt as of today april th who are the three players you want to see liverpool sign and why',
#  'that for one game',
#  'rt stoichkov koeman eusebio guardiola and now juan carlos it is nice to see so many members of fc barcelona s dream te',
#  'rt alqabandi for others it s sport',
#  'rt archie just three seasons ago liverpool s main forward options were borini lambert balotelli goals in apps combined',
#  'pray to god roma knock them out can t be having them at the same number as us',
#  'rt to be honest united looks like a job to jose not a passion he seems like a manager who lost the fire after the chelse',
#  'rt pau pogba and alexis sanchez among man utd stars under threat of being dropped for fa cup semi as mourinho prepares to wi',
#  'rt today is birthday why arsenal fans are asking for him to be sold is mind boggling shkodran is a solid',
#  'rt manchester united',
#  'rt we are liverpool the story continues',
#  'why champions league rule change is fantastic for spurs liverpool chelsea',
#  '',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'well he is a wine farmer after all',
#  'rt juve dates for icc',
#  'rt on this day in a classic',
#  'rt mental to think manchester united once had rooney ronaldo berbatov and tevez all in one squad under sir alex ferguso',
#  'rt my name is scott maarten hefti',
#  'rt jesus christ whoever made this lfc',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt premier league titles',
#  'rt manchester united',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'rt we are liverpool the story continues',
#  'rt barcelona midfielder andres iniesta will move to the chinese super league this summer with two million bottles of win',
#  'rt my favourite part was when no one told me to clap my hands',
#  'oh so many vaya con dios black box revelation admiral freebee deus arsenal goose hooverphon',
#  'rt according to the manchester evening news manchester united are interested in alex sandro toby alderweireld jorginho',
#  'now this is how you do a video for any liverpool fan watch this must watch',
#  'rt depressive menschen sollen in bayern k nftig in krankenh usern festgesetzt werden k nnen als w ren sie straft ter ein rechtsstaa',
#  'rt official vidal will miss the two fixtures against real madrid as bayern confirm he ll be out for the remainder o',
#  'rt harry performing in barcelona',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'l written all over it for roma',
#  'rt have you secured your place yet realmadridclinic',
#  'rt votersuppression is a potent tool in their arsenal it may have been used by pdp elites in election take a look at',
#  'amazing stuff i m not lucky enough to be from liverpool but this touched me big time',
#  'rt looking forward to tonight even though not expecting any points i booked my holiday after the last',
#  'i think man utd and liverpool are to watch for united may bottle',
#  'rt england u defender trent alexander arnold has committed his future to liverpool and is set to see his wages double',
#  'rt',
#  '',
#  'a way of life a home an anthem a guardian a family',
#  'rt real madrid fear that the accusations made about a robbery against juventus will be consequential against bayern they',
#  'barcelona set to cancel move for hector bellerin after gerard pique leads player revolt afc',
#  'rt my favourite part was when no one told me to clap my hands',
#  'where is jeff sessions',
#  'bayern s vidal out for rest of season after knee surgery this could actually have a negative impact on the game ag',
#  'rt theatre opening tomorrow rasheedaspeaking is one of the top theatre shows to see this week in london',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'rt this is amazing this is liverpool lfc',
#  'rt we are liverpool the story continues',
#  'rt apparently jonas hector has a m release clause this summer alberto moreno is yet to receive contract extension so he',
#  'rt last caller on talksport a manchester united fan who wants his team to lose at the weekend just so mourinho gets the sack t',
#  'rt talya n n ba kenti roma da katolik kilisesi ne ba l bir niversitede eytan karma kursu d zenleniyor',
#  'rt martial mixtape vol',
#  'rt we are liverpool the story continues',
#  'they are here mama our husbands who mock us for watching the kardashans but continue to support arsenal we are w',
#  'juventus will allow claudio marchisio and stefano sturaro to leave this summer and may also let sami khedira move source calciomercato',
#  'rt archie goals assists more tackles than any defender from the top pl clubs this season bar azpilicueta a tactical loo',
#  'rt barcelona cathedral roof top inside view april via',
#  'unselfish liverpool star firmino is special says kuyt',
#  'how would he know anyway we had m last summer',
#  'it s official manchester united vs liverpool at michigan stadium the detroit news',
#  'rt back in the states',
#  'real madrid won the title',
#  'headred why would i make an hour round trip to appear on soccer am you mad',
#  'rt we are liverpool the story continues',
#  'rt do you think it was a mistake letting james rodriguez join bayern munich',
#  'rt bellerin is a poof who can t dress embrassment to arsenal',
#  'manchester united s marcus rashford will be playing for more than an fa cup semi final place in bournemouth start',
#  '',
#  'rt we are liverpool the story continues',
#  'ireland star darron gibson pleads guilty to drink driving',
#  'juventus manager max allegri provides injury update on their star',
#  'sevilla full of fan palms caf s historic monuments travel ttot fstravels',
#  'real madrid bayern roma y liverpool buscan la gloria europea pero sabes cu ndo fue la ltima vez que jugaron',
#  'any feedback on our latest episode let s hear it',
#  'rt chelsea funk s senior collection will make its debut at the ccad fashion show on friday may it consists of four look',
#  'rt we are liverpool the story continues',
#  'rt bayern s operation stop real madrid has lost an important agent',
#  'liverpool fc news trent alexander arnold set for huge pay rise after triggering incentive bonus on contract',
#  'rt crazy how since sevilla beat us at old trafford they haven t won in all competions since losses draws our cl campaig',
#  'it s not suchna wild claim let me give you an example blacula soundtrack in renshaw s',
#  'this guy s stupid continues in epi fashion',
#  'psicologia psicologo psicoterapia sostegno relazioni autostima disturbo ansia stress panico scelta',
#  'rt barca laliga jornada',
#  'juventus khloekardashian cannes foxnews gop rnc dnc resist liberal cnn msnbc hannity tuckercarlton',
#  'pogba to barcelona',
#  'rt liverpool s run to the champions league semi finals has already earned them million echo',
#  'rt we are liverpool the story continues',
#  'tuesday night football followed by live music at pm with ben maitland find out more here',
#  'crocked santi cazorla wants to remain at arsenal but gunners sceptical over extending contract',
#  'rt must be personality team of the year after triumph on a great weeken',
#  'manchester united to play real madrid and liverpool in champions cup while klopp faces borussia dortmund reunion',
#  'news',
#  'sql data analyst data owner x liverpool x circa k liverpool england careers a jobs',
#  'rt we are liverpool the story continues',
#  'kyle kashuv owns chelsea handler for most ignorant gun tweet ever',
#  'liverpool target has made more recoveries than any other player in europe s top leagues',
#  'rt stats show roberto firmino has won more tackles in the epl than every other defender at a top six club apart from c sar',
#  'surat dari bobotoh persib di roma gemuruh dalam diam',
#  'rt sport the arsenal board may be at a tipping point with arsene wenger says chris sutton afc',
#  'man city v liverpool champions league programme',
#  'jose mourinho to sell four man utd stars including paul pogba mufc manutd',
#  'rt to all spurs arsenal manchester united chelsea and liverpool fans forget the rivalry don t let this embarrassing',
#  'rt the reds are boss liverpool fc podcast via',
#  'claude puel sends transfer message to manchester united over harry maguire mufc manutd',
#  'juventus face big fight for manchester united forward',
#  'tottenham face brighton as they try and eclipse liverpool who sit in third live from find out more here',
#  'rt happy birthday all the best for you and your family bro yagunnersya',
#  'pie omg chelsea you re the best thank you',
#  'ynwa i see what you mean but juventus asking price for dybala is going to make the man go crazy',
#  'tough blow to for their upcoming game against in the championsleague',
#  'surreal to think over last few days i have been cheering on chelsea crysta',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'rt jesus christ whoever made this lfc',
#  'rt we are liverpool the story continues',
#  'man utd great gary neville predicts jose mourinho s reaction to man city title',
#  'estoy hablando desde que esta en el barcelona pedazo de maquina estoy diciendo que',
#  'lanvin',
#  'rt almada en el rrpp dijo que si sigue asi guayaquil city va a ser un rival duro para todos el problema es que solo frente',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'happy birthday m u s t a f i',
#  'rt barcelona no tuvo un buen partido ayer no encontraba los caminos para abrir la defensa de guayaquil city que para variar',
#  'sevilla is skinnier',
#  'rt use it to build a mosque and pyramid at anfield',
#  'islesapp a frenchie',
#  'if we would have played arsenal at home in the premier league this year we would have won',
#  'to others it s sport to us it s a way of life',
#  'video touzani takes on chelsea academy s young hopefuls chirpingfantasy',
#  'rt celtic a club like no other',
#  'rt we are liverpool the story continues',
#  'rt martial mixtape vol',
#  'rt should bar a be given a guard of honor',
#  'rt martial mixtape vol',
#  'my man has done it again nicely put',
#  'rt',
#  'rt la sagrada familia barcelona spain',
#  'rt we are liverpool the story continues',
#  'arjen robben has a mini tantrum after being substituted but the rest of the bayern bench just laughs at him',
#  'we got some dfb action about to commence bayern better smash leverkusen is all i m saying',
#  'rt jos mourinho is happy for manchester united to sell both paul pogba and anthony martial this summer source daily m',
#  'rt we are liverpool the story continues',
#  'rt international champions cup',
#  'rt liverpool are considering an audacious million swoop for juventus forward paulo dybala source daily mirror http',
#  'more than a club',
#  'jip there is a lump in my throat we are liverpool football club',
#  'abo iniesta yizidakwa straight',
#  'rt man utd arsenal at old trafford could end up worse than the drumming we really are that bad',
#  'one man that would consider this no one else',
#  'everton fan think sam allardyce done a good job over the games against liverpool',
#  'tosin kehinde not recognized as manchester united announce nominees for u poty all nigeria soccer the complet',
#  '',
#  'rt just watch this arsenal goal man',
#  '',
#  'i pick the three',
#  'barcelona en crucero claro que si dinat travel services more puede ayuderate ha hacer el',
#  'leading uk jobs site reports surge in liverpool vacancies in march',
#  'brighton s five remaining fixtures',
#  'rt the ramones in liverpool ramones',
#  '',
#  'girl feeding pigeons in barcelona barcelona spain girl pigeon blackandwhitephotography',
#  'rt barcelonatv should barcelona sign lenglet if umtiti leaves patreon roundtable paulinho efficiency and iniesta replacement tbpod',
#  'love this club',
#  'rt i was when pogba moved to juventus yet i remember how ferguson was desperate for him to stay',
#  'rt happy birthday all the best for you and your family bro yagunnersya',
#  'they ve just said on sky news tottenham are looking to finish the season above arsenal they take on brighton toni',
#  'rt we are liverpool the story continues',
#  'rt betvictor manchester united have emerged as the favourites ahead of real madrid to sign bayern munich striker robert',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt harry performing in barcelona',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'rt th arsenal points',
#  'rt city have spent the same amount of days at the top of the league this season than united have in total in the last year',
#  'this is why',
#  'kellyjoe a rare comparison of j cole former chelsea player and a male duck how wicked',
#  'your stadium is our old home you absolute nipple',
#  'kana bonde tinotsaya',
#  'rt lama betul tunggu ni',
#  'rt we are liverpool the story continues',
#  'rt it s actually just occurred to me that real madrid have knocked bayern munich out of the last x champions league seaso',
#  'rt arjen robben has a mini tantrum after being substituted but the rest of the bayern bench just laughs at him',
#  'kyle kashuv owns chelsea handler for most ignorant gun tweet ever',
#  'rt city have spent the same amount of days at the top of the league this season than united have in total in the last year',
#  'buenas tardes viajeros bienvenidos al talgo sin putos enchufes con destinaci n barcelona',
#  'rt we are liverpool the story continues',
#  'so glad i m only travelling to bristol and not up to liverpool like greg and georgina',
#  'rt suristic athletic club s ziganda real madrid have hit peak form since march when other team as good as their s have faltered',
#  'rt oficial arturo vidal se pierde lo que resta de campa a en el bayern',
#  'rt suristic athletic club s ziganda real madrid have hit peak form since march when other team as good as their s have faltered',
#  'rt mufc official mufc to play ac milan th july liverpool th july and real madrid st july in the internation',
#  'we are liverpool',
#  'rt we are liverpool the story continues',
#  'he now spends most his days sleeping in the dug out next to garry monk',
#  'rt we are liverpool the story continues',
#  'rt this is very good lfc',
#  'kako je salihamid i u bayern doveo kova a rubikon times',
#  'rt it was great to see a mix of artists academics and students joining us for yesnomaybe in bath brilliant to hear their',
#  'pochettino it is not easy to focus on improving the squad city is focusing on just the next three players to ad',
#  'liverpool receive dejan lovren injury boost of roma clash',
#  'rt and argentina this world cup too',
#  'jose mourinho to sell four manchester united stars including paul pogba',
#  'rt revival this new monstrosity in liverpool is the national architecture centre and has been shortlisted for building of the de',
#  'liverpool clear for the hour c with shower rain myweather',
#  'rt suristic athletic club s ziganda real madrid made mistakes at home in the first half of the season which saw them lose a grip',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'right then',
#  'rt jesus christ whoever made this lfc',
#  'rt james penalti de benatia as es el real madrid quieren ganar cada partido y lo intentan hasta el ltimo segundo lo i',
#  'rt we are liverpool the story continues',
#  'arsenal fans wouldn t deserve benitez they can fuck right off',
#  'rt roma barcelona game is a lesson to all ladies never judge a man by the st round',
#  'rt manchester united to play real madrid and liverpool in champions cup while klopp faces borussia dortmund reunion',
#  'kyle kashuv owns chelsea handler for most ignorant gun tweet ever',
#  'rt suristic athletic club s ziganda real madrid made mistakes at home in the first half of the season which saw them lose a grip',
#  'rt de k nnen wir bayern einfach mal abspalten da ist ja furchtbar',
#  'jadi arsenal',
#  'rt we are liverpool the story continues',
#  'matt ritchie on his viral exchange with aubameyang following newcastle arsenal',
#  'rt gyt really proud of the fighting spirit fam',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt potser alguns encara recordaran l horror de barcelona sota les bombes especialment durant la primavera de ara fa',
#  'rt mandzukic could leave juventus this summer for china or turkey juve are following martial morata for his replacement',
#  'horrible from benatia comments such as this warrant punishments',
#  'rt this is very good by on rafael benitez and he s right arsenal could do a lot worse',
#  'confirmed lineups',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'i m gonna go ahead and rt this but you have to promise to stop watching after loops',
#  'rt richard x tickets available for chelsea v southampton fa cup semi next week southview level seats with free programme',
#  'has any manchester united player been consistent this season easy to to pick paul and dig him out',
#  'kimz have they never been',
#  'i honestly think the liverpool fans have a more redeeming character than the press in this country not',
#  'barcelona travel to celta vigo tonight with an point lead at the top of the la liga table will they be tempted',
#  'rt lvaro morata could be offered a quick escape route from chelsea with a move back to juventus source sun sport htt',
#  'rt we are liverpool the story continues',
#  'rt finally we can try emerson',
#  'rt we are liverpool the story continues',
#  'fan that s all rumors for now my feeling is that he wouldn t want to play the bench again and juventus be',
#  'rt psg give him the role of leader he doesn t even come to celebrate the title win how can he look his teammates in the',
#  'rt barcelona ven a pasar un buen rato rato',
#  'official bayern munich have confirmed that arturo vidal has been ruled out for the remainder of the season after u',
#  'i think the question on everyone s lips is will this affect my dream team points chelsea s marcos alonso',
#  'rt we are liverpool the story continues',
#  'rt agent according to reports juventus are interested in resigning chelsea striker alvaro morata cfc',
#  'rt happy th birthday',
#  'rt martial mixtape vol',
#  'rt veintitr s de abril justo aqu barcelona os firmo los dos nos conocemos o nos volvemos a encontrar eso ya depende un',
#  'rt shearer unlike germany or spain up to teams can win the league or to be generous to arsenal',
#  'rt reddit james on returning to the bernabeu vs real madrid in cl of course these two games are really special for me i http',
#  'rt jesus christ whoever made this lfc',
#  'must read',
#  'security protection for the referee juventus real',
#  'bayern midfielder arturo vidal s season over after surgery',
#  'rt we are liverpool the story continues',
#  'abysmal title defences to rival chelsea s appalling premier league effort this season',
#  'rt hughes very very good',
#  'kyle kashuv owns chelsea handler for most ignorant gun tweet ever',
#  'love this redmen lfc ynwa',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'rt we are liverpool the story continues',
#  'rt juventus are working to sign a great striker alvaro morata and edinson cavani are possibilities rai',
#  '',
#  'rt untuk yang ingin tahu kenapa kita mencintai liverpool dan tak sekedar penggemar klub bola lihat video ini abis ini',
#  'rt right then',
#  'rt we are liverpool the story continues',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt tough blow to for their upcoming game against in the championsleague',
#  'so excited to go to barcelona on friday',
#  'rt for what game',
#  'rt monaco are refunding all of their fans that travelled saw their team lose to psg the other day meanwhile at',
#  'if you re happy and you know it',
#  'rt sport the rumour mill manchester united to sell paul pogba',
#  'rt poiis who s better',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'london liverpool street to norwich has been delayed at london liverpool street and is now minutes late due',
#  'london liverpool street to norwich has been delayed at london liverpool street and is now minutes late due',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'thekid both trash clubs tbf',
#  'do not let this happen',
#  'rt martial mixtape vol',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt remember when juve s arturo vidal wanted a penalty for this against real madrid',
#  'rt my favourite part was when no one told me to clap my hands',
#  'rt manchester united confident of landing kieran tierney for m according to reports',
#  'rt i was when pogba moved to juventus yet i remember how ferguson was desperate for him to stay',
#  'rt we are liverpool the story continues',
#  'this is our team and we are liverpool you ll never walk alone',
#  'rt martial mixtape vol',
#  'rt we are liverpool the story continues',
#  'rt morata keen on return to juventus cfc',
#  'rt we are liverpool the story continues',
#  'rt exposing the myth that real madrid are favored by uefa',
#  'rt we are liverpool the story continues',
#  'north korea loses its nuclear arsenal scientists in a mysterious earthquake',
#  'childcare practitioner job in liverpool per hour',
#  'i love our club lfc',
#  'lfc think it wouldn t be beneficial for his trajectory if i m honest might be better to go arsenal lmao',
#  'rt more season of arsene wenger will do a lot of damage to arsenal football club',
#  'rt archie just three seasons ago liverpool s main forward options were borini lambert balotelli goals in apps combined',
#  'rt chelsea defender marcos alonso has been charged with violent conduct following an incident with southampton s shane long',
#  'who',
#  'richard any update on your thoughts about everton finishing above liverpool thank fuck you ain t on sky anymore',
#  'rt we are liverpool the story continues',
#  'this is incredible',
#  'rt so would liverpool the man is injured more the sturridge',
#  'rt we are liverpool the story continues',
#  'wow that is absolutely spine tingling if you re a red weareliverpool allezallezallez',
#  'rt martial mixtape vol',
#  'rt m dicos y enfermeras del hospital guzm n lander de barcelona se lanzan esta ma ana a protestar por la crisis de la salud vi',
#  'rt bridging barcelona belgrade through beograd',
#  'rt most journalists wouldn t have a career without manchester united',
#  'rt',
#  'rt',
#  'cristiano ronaldo looks sharp in real madrid training for la liga clash',
#  'rt in the summer of real madrid signed cristiano ronaldo karim benzema kaka xabi alonso',
#  'rt lt this breaks my heart',
#  'rt we are liverpool the story continues',
#  'new digital marketing agency launches in liverpool',
#  'sevilla focussing on cdr final on sat ben yedder banned muriel out have l a in la liga',
#  'worldpressphoto djeneta right has been bedridden and unresponsive for two and a half years and her sister ibad',
#  'rt is he slipping away from united s grasp',
#  'rt we are liverpool the story continues',
#  'rt our fixtures in this summer s international champions cup have been announced with chelsea set to play matches in sweden an',
#  'rt bayern s operation stop real madrid has lost an important agent',
#  'rt more woe for man utd as their reserves are relegated from premier league top flight',
#  'rt blaithin is currently on a wine trip with one of our suppliers landed in barcelona travelled north across',
#  'manchester united player matteo darmian discusses juventus transfer interest',
#  'i can t be in singapore and pittsburgh at the same time',
#  'if you wanna write about something let s talk about the amazing year mo salah has been having and how he has devel',
#  'rt we are liverpool the story continues',
#  '',
#  'rt my view on pogba is that he s played consistently he s had the opportunity he s appeared many times in his favoured',
#  'i read mo salah thought it was a prank re read',
#  'rt good',
#  'rt we are liverpool the story continues',
#  'rt jesus christ whoever made this lfc',
#  'th april man city win the premier league',
#  'rt hoy se cumplen a os de un gol que el madridismo nunca olvidar gareth bale tuvo que salir del campo para no ser derri',
#  'rt england u defender trent alexander arnold has committed his future to liverpool and is set to see his wages double',
#  'juventus khedira in partenza verso il sud italia destinazione calabria dejan medan',
#  'rt uk on why liverpool fans and now newcastle supporters are so utterly in love with rafa benitez',
#  'rt rakitic when i arrived to barcelona messi came and talked to me if you need any help i m here i will never forg',
#  'rt what a summer',
#  'rt just over months till this man is revealed as a liverpool player',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'rt manchester city have now won the premier league three times in seven years this is what happened in the first of those',
#  'rt lama betul tunggu ni',
#  'pep guadiola has got the same way of playing than barcelona s team and i think we need him for the up',
#  'rt uk on why liverpool fans and now newcastle supporters are so utterly in love with rafa benitez',
#  '',
#  'last gasp lazio stun juventus to win italian super cup',
#  'rt we are liverpool',
#  'rt roberto firmino has won more tackles than arsenal s shkodran mustafi in the premier league this season',
#  'rt manchester united liverpool will play at michigan stadium on july pm general public tickets go on sale april',
#  '',
#  'ayinla spanish super cup did fuck all real won',
#  'never if he leaves he will come to real madrid',
#  'rt we are liverpool the story continues',
#  'rt the league president is a madrid fan and he does nothing to hide it this statement makes no sense',
#  'rt we are liverpool the story continues',
#  'rt bayern m nih arturo vidal in sakatl sebebiyle sezonu kapad n a klad',
#  'good',
#  '',
#  'rt sky live arsenal v southampton southerncameroons get your free content here',
#  '',
#  'rt lama betul tunggu ni',
#  'rt we are liverpool the story continues',
#  'he will sign for psv',
#  'halamadrid',
#  'oh my',
#  '',
#  'my love',
#  '',
#  'go kart mozart chelsea v huddersfield town the cure',
#  'search engine best black blowjob ever arabic sexy teens nudesexyblackwomen teamsquirt barcelona teen',
#  'rt we are liverpool the story continues',
#  'yeah they should have brought him back around the time they sold him to chelsea crazy',
#  'rt archie just three seasons ago liverpool s main forward options were borini lambert balotelli goals in apps combined',
#  'rt this is us liverpool lfc',
#  'rt we are liverpool the story continues',
#  'rt the international champions cup has announced that real madrid will be taking on juventus at fedex field on august th',
# ...
#  'rt listen up david tennant fans there s only days left to book your tickets for the first screenings',
#  'rt we are liverpool the story continues',
#  'rt oficial',
#  'saw this on mute first and thought jurgen only says the this means more part',
#  'the second provided liverpool dont win anything next season',
#  'rt we are liverpool the story continues',
#  'i liked a video liverpool fc this means more',
#  'rt if two great incredibly smart clubs like bayern munich juventus are crazy keen on anthony martial maybe mancheste',
#  'i love you more allie dalle ug i m so excited to see you too',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'londonklubbarna chelsea och arsenal st lls mot varandra den augusti i stockholm peppet',
#  'celta vigo vs barcelona celta vigo to score goals booking points each team over goals in the game',
#  'rt ap ntense bienvenidas las comunicaciones y desde luego la asistencia',
#  'manchester united vs bournemouth live stream info tv channel time how to watch premier league on tv stream onl',
#  'rt td para m el nico equipo mexicano que representa al pa s en cualquier competencia internacional es la selecci n nacional',
#  'rt we are liverpool the story continues',
#  'real madrid vs athletic bilbao live stream info tv channel time how to watch la liga on tv stream online',
#  'rt join us may in barcelona to hear how digital is disrupting the facilitiesmgmt industry and why coworking works',
#  'rt we are liverpool the story continues',
#  'rt kyle kashuv owns chelsea handler for most ignorant gun tweet ever',
#  'is team glazer ever going to have manu play in tampa it s not like they own the team or anything',
#  'rt i love you chelsea ham can t wait to see you next week',
#  'seems i m the only cul not keen on this signing what so ever',
#  'streaming chelsea charms fucking who nude crying anal sex clips nude girls boy shorts woman fucked by',
#  'this is my fucking club love this so much',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'deserved',
#  'noah en espanol where did i say that iniesta and xavi were p',
#  'rt arsenal s away agony',
#  'rt otd united and liverpool meet at maine road for an fa cup semi final replay greatness ensues',
#  'rt we are liverpool the story continues',
#  'sevilla te ha hecho estas contenta ahre',
#  'rt carroll our confirmed icc fixtures in the united states this summer',
#  'oh fucking hell',
#  'what are we doing to humiliate them lool our fault they dropped so many points',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt interesting theory from juventus manager max allegri last week s game in madrid was good for gigi buffon',
#  'rt arsenal atletico madrid paris saint germain to play in singapore for international champions cup',
#  'noooooo y is this not liverpool so jealous xoxox',
#  'rt otd united and liverpool meet at maine road for an fa cup semi final replay greatness ensues',
#  'rt we are liverpool the story continues',
#  'rt we are liverpool the story continues',
#  'rt paul pogba and alexis sanchez face axe for fa cup clash with tottenham',
#  'rt thfc are interested in signing sevilla centre back clement lenglet this summer and are prepared to meet his m relea',
#  'rt good',
#  'what is going to happen to the other special event guns that i haven t unlocked but are still in the ar',
#  'amazing',
#  'rt city have spent the same amount of days at the top of the league this season than united have in total in the last year',
#  'rt most ignorant illiterate gun tweet ever of all of the activists who have sprung up in the wake of parkland shooting',
#  'lfc and proud lfc for life',
#  'rt good',
#  'rt i thought the birmingham accent was bad but you seeeee this liverpool one bin it',
#  'it s ok we know the predictable ending no pl trophy',
#  'rt exposing the myth that real madrid are favored by uefa',
#  'tell him to defend very well',
#  'rt we are liverpool the story continues',
#  'rt interesting theory from juventus manager max allegri last week s game in madrid was good for gigi buffon',
#  'rt we are liverpool the story continues',
#  'rt',
#  'rt',
#  'tax season ends today prom and payday is on friday i leave to barcelona on sunday it should be a gooooooooood rest of the week',
#  'rt harry performing in barcelona',
#  'put your soccer knowledge to the test and you could win a once in a lifetime trip to spain to watch real madrid tak',
#  'rt just over months till this man is revealed as a liverpool player',
#  'check out what i just added to my closet on poshmark ugg australia carberry chelsea boot sz',
#  'rt th arsenal points',
#  'rt harry winks criticises arsenal on his punditry debut',
#  'rt england u defender trent alexander arnold has committed his future to liverpool and is set to see his wages double',
#  'rt we are liverpool the story continues',
#  'holy crap you can finish th and still qualify for the europa via',
#  'rt id musim panas',
#  'manchester united and liverpool to play at michigan stadium this summer',
#  'liverpool right now',
#  'my latest review for this time it s a music gig enjoy bryan ferry philharmonic hall liverpool',
#  'jeg elsker bobby arbejder altid stenh rdt og nu f et tilf jet regelm ssige m l i hans spil f rste mand i presse',
#  'conspiracy theories',
#  'rt he s kindly donated i m doing a big charity thing at the end of the year for national autistic society and he s donated f',
#  'who said i m not originally from liverpool besides you re taking this',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'rt we are liverpool the story continues',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt lion everton fan think sam allardyce done a good job over the games against liverpool',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'rt juli n pr ncipe en sevilla con todos los honores',
#  'rt sheffield',
#  'happy breath day',
#  'rt madrid worried they will pay against bayern for robbery accusations against juve which is pretty dumb as it s been',
#  'berangkat',
#  'rt martial mixtape vol',
#  'sport cristiano ronaldo looks sharp in real madrid training for la liga clash cristi',
#  'i hate arsenal',
#  'barcelona settles on his former son substitute for iniesta',
#  'not sure why arsenal fans get so pissed off at bellerin s fashion though if i were an arsenal fan bellerin could',
#  'manchester united set for milan liverpool and real madrid test at the international champions cup this summer',
#  'rt breaking bayern munich confirm arturo vidal has been ruled out for the remainder of the season after undergoing knee surge',
#  'this could so easily have been cheesy and crap but it s actually fantastic jurgen is great isn t he',
#  'rt we are liverpool the story continues',
#  'the head of la liga having a pop at claiming barca are winning the league and respectively deserving a guard of hon',
#  'rt breaking bayern munich confirm arturo vidal has been ruled out for the remainder of the season after undergoing knee surge',
#  'rt breaking chelsea defender marcos alonso has been charged with violent conduct by the football association for a tackle o',
#  'rt tt man utd great gary neville predicts jose mourinho s reaction to man city title mufcfamily',
#  'con penal pol mico real madrid es semifinalista',
#  'rt chelsea defender marcos alonso has been charged with violent conduct following an incident with shane long the fa has ann',
#  'rt should bar a be given a guard of honor',
#  'goosebumps',
#  'rt uk on why liverpool fans and now newcastle supporters are so utterly in love with rafa benitez',
#  'rt we are liverpool the story continues',
#  'icc schedule features madrid barca manchester clubs liverpool more',
#  'rt excellent column once again from today on the transformation of lfc the unwanted distractio',
#  'liverpool vs ac milan instanbul',
#  'rt en the last meetings between tonight s two semi finalists',
#  'real madrid vs athletic bilbao live stream info tv channel time how to watch la liga on tv stream online',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt jesus christ whoever made this lfc',
#  'rt lara brutal foto mural en la manifestaci n masiva del domingo a en barcelona',
#  'arsenal were unbeaten against newly promoted teams until they arrive at the amex',
#  'mil or we could just pay toby',
#  'rt roma sgominata un organizzazione criminale italo albanese dedita al narcotraffico tra belgio italia e albania arrestate p',
#  'i love this game',
#  'cowboys are the most valuable franchise in the world at bil real madrid is nd at jerry is goi',
#  'rape analogies in big ffs',
#  'it must be a unique situation a manager who has caused years of decline and failure',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'rt emile smith rowe had a sensational solo run in the arsenal vs blackpool youth cup game afc',
#  'rt harry performing in barcelona',
#  'rt such a great read',
#  'rt supporting liverpool is a story and you never know where it will take you it is unpredictable it will give you lows it',
#  'rt isco shines to lead real madrid to a relatively comfortable win in malaga',
#  'rt monaco gave fans a refund after they lost to psg this weekend',
#  '',
#  'de ligt and martial joining bayern',
#  'rt when had days like these',
#  'jonesafc puma make absolute awful kits pumped for this to be the last year nothing they can produce would be good',
#  'rt cristiano ronaldo vs juventus',
#  'rt we are liverpool the story continues',
#  'rt mercedes giovinazzo director of interarts and anna l pinto project coordinator for interarts are opening today south',
#  'rt we are liverpool the story continues',
#  'when jamesbeattie had days like these',
#  'rt remember when people were tweeting this painful',
#  'rt proud to support liverpool me',
#  'rt roman s having sex again by nikkiashton',
#  'rt',
#  'rt roman s having sex again by nikkiashton',
#  'rt we are liverpool the story continues',
#  'filmstruck films that made you fall in love with cinema tag yourself in',
#  'rt achtung achtung',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt martial mixtape vol',
#  'rt happy birthday to arsenal and germany defender who turns today',
#  'rt ltima hora el real madrid renuncia a sus champions y pide disculpas',
#  'rt barcelona ven a pasar un buen rato rato',
#  'rt we are liverpool the story continues',
#  'rt ayinla for those who think messi s goals for barcelona in the season was ordinary and overhyped',
#  'we are a family',
#  'rt bayern m nich recibir a real madrid el mi rcoles de abril en la ida de las semifinales de la champions f tboli',
#  'rt psg give him the role of leader he doesn t even come to celebrate the title win how can he look his teammates in the',
#  'rt real madrid penalty row has given gianluigi buffon shot of adrenaline he needed says massimiliano allegri',
#  'rt foxsoccer it was a foul it was a penalty it was a red card',
#  'rt last caller on talksport a manchester united fan who wants his team to lose at the weekend just so mourinho gets the sack t',
#  'manchester united vs bournemouth live stream info tv channel time how to watch premier league on tv stream o',
#  'rail im talking after pm do i go fenchurch or liverpool',
#  'rt hotspur tottenham hotspur s last five results during the season',
#  'rt manchester city manchester united arsenal and tottenham are all interested in signing leicester city defender harry',
#  'rt when had days like these',
#  'rt direzione roma oggi sar a geo su per raccontare la biodiversit del suolo lucas il gruppo di ricerca su',
#  'rt jose mourinho to sell four manchester united stars including paul pogba',
#  'rt hundreds of thousands of demonstrators took to the streets of barcelona to demand to call for their leaders release from pret',
#  'rt city psg y barcelona vs liverpool roma y real madrid ganar la liga o la champions league cu l tiene m s m rito lo p',
#  'when you put it like that then van dijk sounds like a bargain',
#  'rt pity that the premier league looks so dead now we ve got winners we ve got a top four chelsea will finish th slight',
#  'rt mohamed salah in for liverpool',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt could all reds give iive a follow the best place on twitter to watch liverpool for free every match day',
#  'rt jumpersforgoalposts club history podcast',
#  'liverpool was made for me and i was made for liverpool',
#  'sitting next to someone wearing manchester united jersey boo',
#  'rt what a summer',
#  'rt l economia cat no nom s no pateix x proc s si no q des q va comen ar proc s no ha parat d cr ixer sostingudament pq',
#  'rt we are liverpool the story continues',
#  'rt enough of arsenal and chelsea bring man utd and liverpool to sg',
#  'sisi kama manchester united hatuko kwa fight ya top four it s a guarantee fm bangaiza',
#  'rt algeria rimpatria mille migranti illegali subsahariani sotto la supervisione dell organizzazione internazionale per le',
#  'rt we are liverpool the story continues',
#  'rt win tomorrow at bournemouth regain a point lead over liverpool lose we re back in the mess essential to finish ab',
#  'rt martial mixtape vol',
#  'rt jesus christ whoever made this lfc',
#  'rt we are liverpool the story continues',
#  'rt isis fighters are heading for the house russia was going to shoot down our missiles never saw them didn t hit one every s',
#  'rt arturo vidal underwent surgery and has been ruled out for the rest of the season therefore missing the champions league ma',
#  'yes cos the juve bayern and reals of the footy world wouldn t turn them into shish kebabs sit down i m all for yo',
#  'rt they have a stadium we have a home they have songs we have an anthem they have a manager we have a guardian they h',
#  'rt jesus christ whoever made this lfc',
#  'you may not believe this because of lazy journalism but i started the wave at the rose bowl whe',
#  'lemme you were the one who said roma is winning that day how come i didn t block you',
#  'rt martial mixtape vol',
#  'rt chelsea s crew',
#  'rt necesito por favor m xima difusi n a esto nos hemos encontrado a este precioso gato encerrado con cinta aislante en una',
#  'arsenal',
#  'we are liverpool this means more',
#  'i liked a video liverpool fc this means more',
#  'jk should be a real madrid sticker on it instead',
#  'rt when you re about to score but you have to check if harry kane is coming to steal your goal',
#  'rt panathinaikos real madrid ma nda konuk tak m toplam ka asist yapar',
#  'bueno bueno la not cia es que lunes sant jordi estar firmando mystical en la fnac del centro comercial',
#  'rt we are liverpool the story continues',
#  'rt wenn man in bayern wohnt und tweetet dass man sterben will',
#  'rafa m rquez revel que ronaldo impidi su llegada al real madrid',
#  'rt blaithin is currently on a wine trip with one of our suppliers landed in barcelona travelled north across',
#  'rt losses to bottom sides this season',
#  'i am even happy hearing this the fact that madrid and tebas liga president is triggered',
#  'rt anna caterina antonacci has achieved something extraordinary with this gloriana a performance to be remembered',
#  'rt martial mixtape vol',
#  'like i want arsenal to get to that level real madrid level but then when i think about it we re way off i m su',
#  'exactly also he has previously stated that hes mkre manu than liverpool besides bobby is irreplaceable',
#  'rt wenn man in bayern wohnt und tweetet dass man sterben will',
#  'rt we are liverpool the story continues',
#  'rt voting is now open for the chelsea player of the year award',
#  ...]

# %%
df.shape
# Out:
# (41640, 1)

# %%
nums = [0,10000,20000,30000,41000]
print("Cleaning and parsing the tweets...\n")
clean_tweet_texts = []
for i in range(nums[0],nums[-1]):
    if( (i+1)%10000 == 0 ):
        print("Tweets %d of %d has been processed" % ( i+1, nums[-1] ))                                                                    
    clean_tweet_texts.append(tweet_cleaner(df['text'][i]))
# Out:
# Cleaning and parsing the tweets...
#
# Tweets 10000 of 41000 has been processed
# Tweets 20000 of 41000 has been processed
# Tweets 30000 of 41000 has been processed
# Tweets 40000 of 41000 has been processed

# %%
clean_df = pd.DataFrame(clean_tweet_texts,columns=['text'])
clean_df.head()
# Out:
#                                                 text
# 0          islesapp wow brave people bit cold for me
# 1  rt they have a stadium we have a home they hav...
# 2  rt sport king of spain philippe vi confirms hi...
# 3            rt we are liverpool the story continues
# 4  panathinaikos clear ex chelsea star michael es...

# %%
for i in range(0, len(clean_df)):
    if clean_df.text[i][0:2] == 'rt':
        clean_df.text[i] = clean_df.text[i][3:-1]

# %%
clean_df['tokenized_sents'] = clean_df.apply(lambda row: nltk.word_tokenize(row['text']), axis=1)

# %%
sid = SentimentIntensityAnalyzer()

# %%
clean_df['sentiments'] = clean_df.apply(lambda row: sid.polarity_scores(row['text']), axis=1)

# %%
clean_df.head()
# Out:
#                                                 text  \
# 0          islesapp wow brave people bit cold for me
# 1  they have a stadium we have a home they have s...
# 2  sport king of spain philippe vi confirms his a...
# 3                we are liverpool the story continue
# 4  panathinaikos clear ex chelsea star michael es...
#
#                                      tokenized_sents  \
# 0  [islesapp, wow, brave, people, bit, cold, for,...
# 1  [they, have, a, stadium, we, have, a, home, th...
# 2  [sport, king, of, spain, philippe, vi, confirm...
# 3         [we, are, liverpool, the, story, continue]
# 4  [panathinaikos, clear, ex, chelsea, star, mich...
#
#                                           sentiments
# 0  {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'comp...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.272, 'neu': 0.578, 'pos': 0.15, 'com...

# %%
new_df = clean_df[['text','sentiments']]

# %%
new_df.head()
# Out:
#                                                 text  \
# 0          islesapp wow brave people bit cold for me
# 1  they have a stadium we have a home they have s...
# 2  sport king of spain philippe vi confirms his a...
# 3                we are liverpool the story continue
# 4  panathinaikos clear ex chelsea star michael es...
#
#                                           sentiments
# 0  {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'comp...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.272, 'neu': 0.578, 'pos': 0.15, 'com...

# %%
a = []
for i in range(0, len(new_df)):    
    a.append(max(new_df.sentiments[i].items(), key=operator.itemgetter(1))[0])

# %%
new_df['Sentiment'] = a

# %%
new_df.head()
# Out:
#                                                 text  \
# 0          islesapp wow brave people bit cold for me
# 1  they have a stadium we have a home they have s...
# 2  sport king of spain philippe vi confirms his a...
# 3                we are liverpool the story continue
# 4  panathinaikos clear ex chelsea star michael es...
#
#                                           sentiments Sentiment
# 0  {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'comp...  compound
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       neu
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       neu
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       neu
# 4  {'neg': 0.272, 'neu': 0.578, 'pos': 0.15, 'com...       neu

# %%
new_df = new_df.drop(['sentiments'], axis = 1)

# %%
new_df = new_df[new_df.Sentiment != 'compound']
new_df = new_df.replace('pos', 1)
new_df = new_df.replace('neg', -1)
new_df = new_df.replace('neu', 0)

# %%
new_df.head()
# Out:
#                                                 text  Sentiment
# 1  they have a stadium we have a home they have s...          0
# 2  sport king of spain philippe vi confirms his a...          0
# 3                we are liverpool the story continue          0
# 4  panathinaikos clear ex chelsea star michael es...          0
# 5  chelsea winning against spurs is by far my fav...          0

# %%
X = new_df['text']
y = new_df['Sentiment']

# %%
text_clf = Pipeline([('vect', CountVectorizer()),
                      ('tfidf', TfidfTransformer()),
                      ('clf', naive_bayes.MultinomialNB()), ])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
print("\nFitting training data using Multinomial Naive Bayes...")
text_clf.fit(X_train, np.asarray(y_train, dtype = np.float64))  
print("Model fit.")
pred = text_clf.predict(X_test)
print("Accuracy of Multinomial Naive Bayes model: ", np.mean(pred == y_test)*100, "%")
# Out:
# Fitting training data using Multinomial Naive Bayes...
# Model fit.
# Accuracy of Multinomial Naive Bayes model:  93.7442137283 %

# %%
text_clf1 = Pipeline([('vect', CountVectorizer()),
                      ('tfidf', TfidfTransformer()),
                      ('clf', SGDClassifier(loss='hinge', penalty='l2',
                                            alpha=1e-3, random_state=42,
                                            max_iter=5, tol=None)),
 ])

# %%
print("\nFitting training data using SGDClassifier...")
text_clf1.fit(X_train, np.asarray(y_train, dtype = np.float64))
print("Model fit.")
pred1 = text_clf1.predict(X_test)
print("Accuracy of SGDClassifier model: ", np.mean(pred1 == y_test)*100, "%")
# Out:
# Fitting training data using SGDClassifier...
# Model fit.
# Accuracy of SGDClassifier model:  93.5987303267 %
